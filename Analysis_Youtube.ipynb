# %%
# pip install google-api-python-client
# pip install oauth2client

# %%
from googleapiclient.discovery import build

# %%
youTubeApiKey="AIzaSyAC7mWnqrsycOKvMAKmdG5r3BB-3PpFPjk" #Input your youTubeApiKey
youtube=build('youtube','v3',developerKey=youTubeApiKey)
youtubeVideoParts = 'contentDetails,id,liveStreamingDetails,localizations,player,recordingDetails,snippet,statistics,status,topicDetails'
youtubeVideoChart = 'mostPopular'
youtubeVideoID = 'vtPK0feHhSs'
youtubeVideoMaxResults = 1000

# %%
import json
import pandas as pd
import numpy as np

# %%
listFile=[
          '/content/drive/MyDrive/scraping_data_01.txt',
          '/content/drive/MyDrive/scraping_data_02.txt',
          '/content/scraping_data.txt'
]

# %%
f = open("/content/drive/MyDrive/scraping_data_01.txt", "r")
out = open("/content/list_id_01.txt", "w")
urls = f.readlines()
listIDs = []
for url in urls:
  id = url.split('?v=')[1]
  out.write(id)
  listIDs.append(id)

# %%
out = open("/content/list_id_02.txt", "w")
listIDs = []
for file in [listFile[-2], listFile[-1], listFile[-3]]:
  f = open(file, "r")
  print(f)
  urls = f.readlines()
  
  for url in urls:
    id = url.split('?v=')[1]
    if id in listIDs:
      continue
    listIDs.append(id)
    print(id)
for id in listIDs:
  out.write(id)
print(len(listIDs))
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#
# EHshnIeJD_Q
#
# O8Sw2pb-0wg
#
# Z892dyjVey0
#
# 9e_rBcu7cMs
#
# wUWqjucvTrE
#
# EIAU2uGbxto
#
# eM0JyMYlYiE
#
# 6L71Z8XqcqE
#
# NZHnFVSP1No
#
# e6h-8HyySKs
#
# eIGw9N8U0Z8
#
# KaxgA47u3Vg
#
# 3KNxiacwfuQ
#
# Z5WIFEM-kL4
#
# tqEHPmBlZ64
#
# DczGFMlx75o
#
# lU5NFbunmeM
#
# z4Be0u0tQfc
#
# juzSlvWmKBg
#
# zNXP0BaLKEA
#
# 6XP1Bp-PF2s
#
# 5mfufrFY_VA
#
# oegHn1HI27Y
#
# JgorEs6aG_o
#
# W8canQvaWmQ
#
# WCmpcMK780w
#
# yUvdMFK9_-o
#
# 2B06oXaw5DY
#
# LjySeUTXRZA
#
# Ken8lUa_c2U
#
# k5kgSKEbxcU
#
# yCZbRQzeB_k
#
# Y_qgUC5i-P8
#
# ZCE-TIHNskc
#
# ZcGUErvZHys
#
# rICswlHU8Xs
#
# dL6xrwMHxy0
#
# LUkp9qDE5is
#
# 8WiydQOjFms
#
# 2RFmkr-Gyco
#
# QsgGfuQExBQ
#
# ooNMjBDPGvM
#
# 84cnqAtwIu0
#
# JL2RVCMOCNI
#
# LLz_C73vlEQ
#
# PmysPi_rRU4
#
# J1IzVxKIW8A
#
# aUIuHz30xL0
#
# Tox-rD0MJ0k
#
# kJPb2cNbJt4
#
# T89Fpx1F9xo
#
# eF9KW9M0wB8
#
# 9SMLc9oCN6Q
#
# 2KaiVLtKNVA
#
# CbZoy9HQQwo
#
# VY5NQJTOanw
#
# ZJNvUedEZDA
#
# YBXzD9R-Amo
#
# WV8-Vdwsrsw
#
# wDbYqcbCAUg
#
# S4FP0oGJKPE
#
# rEcKeEnJeOo
#
# WO-n4QBjKJ0
#
# qrjQdSfjNGo
#
# kHuHNHjPXvo
#
# 7tMVLd1zKy8
#
# t_rm0GsYkqc
#
# 6cjjF9vK0gM
#
# xS78Ptk4W6s
#
# Yx9VabOCKpI
#
# LEWtfRrpW7A
#
# jyGTO1e7xcA
#
# SNttk940IMQ
#
# SMRp-NqHSeI
#
# QnssjgokfVY
#
# l-fIjfcg5f4
#
# kALth_PWMxY
#
# Edx1sx08hIE
#
# EFu4VxD_9Z4
#
# 1IlixOrf2pI
#
# XHdAW4cWelI
#
# p8XDkSASNj4
#
# G-GVs652gSQ
#
# K-DZFBKOeds
#
# Bt4fvMSwOJM
#
# JcItxbLjhuo
#
# -etkAhRQSAU
#
# 52B7zMCzpqM
#
# 92lD3lSxIDs
#
# bMebhJTODkQ
#
# NOED-HG6d54
#
# VLsVjry_NYE
#
# iCjHw1lUi90
#
# 7w_n1LBafbs
#
# lNvFLzz-gr8
#
# 8IRVC68tiH4
#
# O949MsBX9-E
#
# zsTSVfbPmJw
#
# Sfya39KMwK8
#
# 76YQ8RxQ3ZY
#
# 4sUhae8DiU8
#
# 7k0oIvk0AQ0
#
# N2Y1KSrqCBs
#
# dtTZGKLi0hM
#
# tfKXyEn42EY
#
# MNiUFGHXydk
#
# wuzrIGKVVhY
#
# zgCgynMWVwo
#
# l-WOO_I1I1c
#
# 9PPPkE-bg0E
#
# oEpLCCcAGck
#
# yTAXtFLD1mk
#
# iLm1hXM24zo
#
# mHQEFE1MGS4
#
# XsyvkDKyzB0
#
# EzJDAEhRPXA
#
# aCSIbwKEsd4
#
# UAFrRWjwsh0
#
# 0gn8RPrw6AA
#
# IuwBsxUSRio
#
# 3mZ2b4CGyBk
#
# 446Xo6pHLf0
#
# hG5xfN1_gik
#
# BZNcM7ROi7w
#
# nnmy9SXsG0k
#
# utWD3ksPbXM
#
# R1ccZrXnHUo
#
# Zrod-hU29X8
#
# apFlw3I2BTY
#
# PKFE2ueqb3E
#
# GEPPKTGaQ-k
#
# 4wWgUHousxE
#
# FHrSV_kHcLs
#
# YadDk-YApks
#
# aY_OX4ABzv8
#
# nNUy41PdaJA
#
# 9sfUdaBqwfs
#
# e123d8wOB2o
#
# 8dqNnyWAth8
#
# zZesXXryWxM
#
# a_3lbgO21O0
#
# 1-PGs0AYryo
#
# 8UXRoH3a4Ks
#
# Lev7NoS3NW0
#
# ZicAjBTYcbE
#
# Ny2OzbWP29o
#
# ZUHv8vsvsTA
#
# ZCG3RvX-wAw
#
# m_eMA9JcR3k
#
# WKvSh8JhpuQ
#
# 2IMISX8vPp4
#
# 8rdRZCiwmA4
#
# 84GpkS9g5fU
#
# 6tNQcvazZZo
#
# InWy2F2hvtQ
#
# 9bcF5Y08HWA
#
# 7kvg0ZjSy_U
#
# 3lua72x4uUU
#
# xITX2bfbSPY
#
# WHogWac1BFs
#
# RKooUKU_pY8
#
# iCeyvG7FYnI
#
# cQqBcx72lng
#
# 6uWUDhlCd9E
#
# 5AF9Wac0APc
#
# WKFncuFbzC0
#
# LS-0NY5jhk8
#
# v1NTh7tvh_o
#
# XQirc4zVKlc
#
# yNyt1RfuCT4
#
# 1aaJr97KBVw
#
# HZoWrX-X5NA
#
# OnmlY_uynJg
#
# D4dq09LEImI
#
# OaJ4DEuK2G4
#
# cwRz36tkc5k
#
# jtAukKX-5WE
#
# zZ_d5eBRin8
#
# YgI45_42LeM
#
# eDJpcT-JNtw
#
# fh6DFZtWRLk
#
# mKl75zyNLIQ
#
# s0NuUEt4N7Y
#
# kDjYNkH8who
#
# ZS2gMknw_7M
#
# AoKp0x7-z78
#
# T6wIuz3O8Q4
#
# k21t8TwTkWg
#
# S_zGGNaIpJ8
#
# Y_oBgYBum-I
#
# DhLl9Kar16M
#
# oHHVMJ0UEjc
#
# VyjYYUwXo4M
#
# nyoVQCRUXU8
#
# -HUNFzuyFvA
#
# oBAhHgo5vBM
#
# ACVlxpzj2-k
#
# 9rOwmxuVlbs
#
# GW_1J3bwrCc
#
# eD4oYiGZFBI
#
# wUNzEu8QdyM
#
# WtgeN_whIbY
#
# EFsY9W6POUI
#
# GTt6WPGzDpU
#
# oBkhLmzhVFM
#
# ggkaMIKBj54
#
# 5BJ_1m17DJw
#
# Z97cSrQ5sGo
#
# JRHFTui4URs
#
# 5pciCMvgrbc
#
# vsNIGBORBzI
#
# OLiUeF0qAg4
#
# vcbDW5q12ZM
#
# zKmO60Q2Crc
#
# 5A0zWGKKXew
#
# hoYEVq_52_g
#
# 8n_9zy1E2UQ
#
# vpM2MdSYJrM
#
# u08-Ok6LsOU
#
# ME1Pe7ZIpTE
#
# oU_dlAEBTTY
#
# zlE5sy9O3IA
#
# pYzhPXQ8Jok
#
# d5K2bBNeprI
#
# i3R-xD_InWk
#
# HLd1yWdfPng
#
# T4FBkC0Hm5Q
#
# I-T7NOPEb_g
#
# N3GdX7splS4
#
# 8Ea8vx6Z7H0
#
# yU399tAQ058
#
# 9D-uunIMfv4
#
# 6qhJzk-3S3E
#
# LE-UOpwFR-4
#
# juQITHDVvvk
#
# yzEs0y7oLHI
#
# GtXkdeiYFNM
#
# z4ZHqolcTCE
#
# 9mAfBjJalmc
#
# gE02O3Jnm54
#
# CPo9VrCJK0w
#
# zY2P01MF-xk
#
# qy9cAbV5ag8
#
# FnlSNqK2cuI
#
# hzOEPWBu9Yk
#
# 6fYw_Mbo5eM
#
# w0Lik2RIrEo
#
# guFyuvIl81c
#
# Ur_-vT7TxlI
#
# UDcKdA926yc
#
# cwLw8bd9Gvw
#
# 2WaCK6IirtM
#
# OyipGKP5kDg
#
# TM6Pox-IGvY
#
# tsh3rbC8UrE
#
# 3kzOVtjCbqQ
#
# hzotfGogWBQ
#
# 3ZaAzjQheRQ
#
# cMz1_RWFwNw
#
# rDnYW5jwXVk
#
# ynYapqU40pE
#
# 5MDvKDjzp8U
#
# Yq-s2W0PIoY
#
# PZ1B-sNhUtc
#
# ogaOw4i1dr8
#
# BzyvMg0eZOY
#
# z-8kzd_Me4s
#
# kzo4gNP6Snc
#
# we7fgMOUGRQ
#
# ftZoxYiJbdM
#
# PrtUZKKHp-s
#
# dpDZrkj-TzU
#
# hg0VVDd4sfs
#
# peNrihdMTYU
#
# _gVlcBWenOA
#
# clazSH-DH0I
#
# iBGrStmzlTQ
#
# -9AP19mdBtk
#
# WbHI2Lb0pNI
#
# fFCD8i8LK8g
#
# DzZqT_kO2Is
#
# uLn8FaQKcBQ
#
# d5VossM0Cs0
#
# QCT6FdfzMKw
#
# KSJdO2DJGNM
#
# TWz3es1UthY
#
# FoAwMFpMDeA
#
# x4dZ4Mp4VWU
#
# tsNJLlayN1w
#
# 8ZtICCVil8w
#
# nvvHsQLHjEM
#
# _ZNbTcbr9DQ
#
# 7GiDXvRx38s
#
# UldwftGFKuk
#
# L8xZGyFZsmw
#
# BDyjiyyDpbc
#
# KiY3DK-SPS8
#
# roTclgm8gv8
#
# h8IIOX_RRjw
#
# qUXhuMnRXtg
#
# -JiCjYTZ03o
#
# 9xDyGrsoQDU
#
# 1WG6O5QkN2g
#
# 4aZZCM5u_BM
#
# VMHBw-sTXsw
#
# MFaVlU28l2g
#
# 4PtnCmPTnuk
#
# _vVLOzs7B9k
#
# yYDPLoaH92A
#
# DGM_IXMd_Qg
#
# B_UIckbVFiI
#
# r9BmuFvG5LM
#
# SbyOaAKja-E
#
# uDGMngIJiIg
#
# XIvVOaH5GoY
#
# 6-7u_vZYw0A
#
# Qt5qm1SQtWc
#
# opycLXmca2Y
#
# tuaOX9turAg
#
# HdtgPOO30n0
#
# u0WhMc1GWHU
#
# C1pMppHhVXs
#
# 5Bo1o-ubSuI
#
# vjg2oyb8n3I
#
# QzreI5cDyTY
#
# _E3ez8tuhUI
#
# 2gThdoRJ06s
#
# gBedN6vRDj4
#
# JxELxoQjRF8
#
# auBJUWMbiNM
#
# sUdVfEobx-M
#
# jdjmQ8ClXj0
#
# SGRvFzXxKCg
#
# 4WQGs_ktWkE
#
# -7_1oouOHqs
#
# pGBQddwCqbw
#
# wb4hjb3xr-M
#
# XLopS9lzljg
#
# 3iSamv2qUHE
#
# d2zf0x2zPgw
#
# BkgTp11p4nE
#
# ca-r0uZvRXs
#
# a1Ljn8MFFEE
#
# 83qrevuWTbQ
#
# UQ8bjeCsmHY
#
# cpSEoMiDG0A
#
# 5zcPnzDD5ZI
#
# Y4lizLpEc4U
#
# TtmFD6E1W98
#
# 5D-z9R7KOJw
#
# n5Pbqq7tFag
#
# WczxVEjIGBA
#
# Z8VVJ3n3VTM
#
# Jypw1EYCO7k
#
# iC8QuUGq0eM
#
# E5rfCkgMY5Y
#
# WO2enhNPiUc
#
# lO9vT1Sj8bM
#
# mV3xAsUtRmY
#
# -DqGWRLNwIo
#
# lZaC3i1FKn8
#
# FIpod_TAoYE
#
# VCIh2BljpN8
#
# c1MiGvnTa7Y
#
# yGT4kIRr44Y
#
# Kz3sF4kUXGw
#
# Ukl97dhJNnI
#
# qqBf0TCfAlY
#
# kIOenV12Ilk
#
# ynianyjNDcM
#
# NJF0Kk3Rlm8
#
# w8-ODPMB-dM
#
# QRMEQIoNlGw
#
# xSKrZhhTlEQ
#
# y-nZpTCpySA
#
# f2f_kn6QXT0
#
# JnzBN0cY3co
#
# xo9crG0SJvg
#
# DGefcrx0vCU
#
# 7VLl3yGK8Ik
#
# UmyAAcMRItM
#
# X-ovlo0RKjE
#
# Jgt4XpRNotc
#
# p0iAk28miCU
#
# HOq2SVXCikQ
#
# OmD1lDIGW3U
#
# JV9xEkyrxI4
#
# y5Xf8mFzukE
#
# cYtrWqCn440
#
# 8jY9IsSH7x4
#
# N2Pi4_1Ptqk
#
# vCrHBJ9OyfQ
#
# 9s1GMoUK9ME
#
# BnIWVYTgbl8
#
# GghFYyyMl3g
#
# kwnovsaiA08
#
# 2b9rKW60v9w
#
# yjL2t7NyUlw
#
# 94ZNnE56nmY
#
# X8AgwFrJm_8
#
# 2t1hfMqskLs
#
# 4RLSBIYi_30
#
# Q5p_kel-PsQ
#
# 0OlVNMBrq5s
#
# kZJRT5Xk-YY
#
# aTKEx0lp6M0
#
# WfcySuwxmLI
#
# gCqsSSN_-CY
#
# Wu6FDHcVtxE
#
# e0xttRcmY0A
#
# xdTUahAruz0
#
# M-fWC2dbWsY
#
# 6-sClsOnWaE
#
# ZsIV3QYUCTU
#
# l5_AAbp8ZGA
#
# H2gX3II7WB4
#
# p3pgHjQgD0I
#
# k6mNIW9uN9g
#
# kfYRVJs4t4A
#
# KZK1Nz6RkbM
#
# kMWm_vQ2c6s
#
# VP_srkz6D_4
#
# H-ISI7hY2Ks
#
# w021MCxquxg
#
# 1cASjevyogk
#
# RxB_4O7JWrw
#
# JZrhwaOVU8M
#
# 5UvzWS7nBco
#
# HdHsnFGJI3E
#
# KMDLdREGNrg
#
# HQ46-r5iLNE
#
# XvAwq01Liqw
#
# Z-MVIyr_Wss
#
# j02lOGT0_-E
#
# 3qNoDw8gdyg
#
# eWHFSsdhz7k
#
# Is7AtGNrc_Y
#
# AMqLRca-Ni0
#
# QUhcOLcApLc
#
# dn4b9TcEEoo
#
# tmVRoA0qWMs
#
# K-y1oR3p-FA
#
# tPxDL4E9ydc
#
# GVAjwZXc304
#
# RJyMhAfM1QY
#
# qWTGY1B5WrU
#
# 71KoyW-Cg-M
#
# G_fGGsw7eoM
#
# kGawyoHCBk8
#
# Y18eTp5bHig
#
# jhFjL1QUqNM
#
# n-Lf6MTET_M
#
# fVcbhHuiU08
#
# 5oAdTxp95dk
#
# FQxyIz_hncY
#
# SRdDCC2JvxE
#
# zFhF5R1WBcY
#
# rZka0Z5Ml0o
#
# xl0r93fr8pg
#
# cyFCkx7oOI0
#
# NcpzNp4vvj8
#
# uOLSpBkpSLA
#
# NtWb-wrxaGE
#
# o2FNUvY-5lg
#
# 0dMsSYw0A0k
#
# IhhvQGdou2Y
#
# dFXEfFj73YA
#
# 0pJF19JCcVY
#
# OuCjSIMJ_GU
#
# vvQQSlU2l9U
#
# pPHGdYmk9Lo
#
# 1juIFmPyG-Y
#
# 3pi9kk40nyk
#
# 2HRVCJJNOzg
#
# -upQhCwTO90
#
# UYIUKFgA_OQ
#
# 5jqjEEMvYUA
#
# 5rN5ArisCP4
#
# 1KBBCJZI3-A
#
# Kuygwgxvf1c
#
# w04uvHJvud4
#
# i8TmD4YiBCk
#
# H66T-bxZ1Xk
#
# oBVkpAeeZ_g
#
# aXQPRokHfzM
#
# XCyL9o4PSnI
#
# WWxDATS_pkk
#
# y07u78IVRRg
#
# j4wzxb5QKkY
#
# AqPk7YYHt1Y
#
# fjzg_RB8wYk
#
# KObOaXFrQng
#
# ekfyAcumMpk
#
# _XWzCHJKYfY
#
# x4IwuZ7asH4
#
# Hr1s_XQ-vvw
#
# 8ElJRrLqcVY
#
# I7dhM7SJP6w
#
# 8TUKCnqEo34
#
# 5kUi4dqCQ5A
#
# 3xFAk1j5Be0
#
# NzRwvEbj62E
#
# dvRmjpYQrvA
#
# 6P8-JpAO8yE
#
# S6TeD7l2oUw
#
# lqDaFNrk3iY
#
# i2r6zyAYxYE
#
# _5-MVqtFlGc
#
# 8Wk7q-ayAmE
#
# 9pTZKDq4ZgM
#
# SVUo4C1oSbU
#
# Ogoo9SMzOAE
#
# i_C6JDAdQyg
#
# OVbzZv1h3B8
#
# 0gHY-o9bDYo
#
# eMtC5Sd3juk
#
# vlOnCWq2Ag8
#
# ykF393G3cys
#
# qfqcEXc_TqQ
#
# eNAIijUEhbg
#
# aX2MdjHIkxs
#
# b48eIO5xo-0
#
# eNUMr4hz5oE
#
# aGwzXk9bKPw
#
# 2Udr8SxRJ_I
#
# wR6Zn7KZi2g
#
# wssbBe_t-r4
#
# h-hwMOa9Ce0
#
# YdIkpSlMhJ0
#
# QGoadp5qC7s
#
# VLq-0gd2224
#
# m0Sjc_6ldnI
#
# l-KGyniGgLw
#
# JsSt8nnQHK4
#
# 8IrQEW3iBlA
#
# FXvo1Bf4Oxc
#
# giKjJ1bzmzg
#
# 8BklZUtBiQM
#
# L5F82SwYTrI
#
# 9AJp59Agafw
#
# 8FZRYxovQws
#
# wsjs32NiXz0
#
# ZLet_nxieKQ
#
# fMuyANfu_74
#
# RxqOJXNZXrI
#
# gTXEYICpUCI
#
# jJLcV58NndY
#
# xaZkN9WmjQA
#
# SCGCOYKbM10
#
# 6auH46J4TzU
#
# Ev_-WOh7Wy8
#
# LMUwmogj7fs
#
# keCFnn0pPGw
#
# pi2PVono8_Y
#
# gNtFuMllyHM
#
# XgKLG3cafPk
#
# 8rZQa0dSLN0
#
# wrKg7ypkXhE
#
# d_3wOdUrTz0
#
# 1Hj0cVKgaDA
#
# SnIajtec1Yw
#
# GN33XE9O4JA
#
# awgllxtKB4g
#
# wU_VwmXKmpo
#
# kJwMnNzo89Q
#
# fd8wK4WiiNM
#
# UXRmkWPGvnU
#
# N9W6FlC7YcU
#
# ERhOvpUMDeU
#
# 3aNPaEOPJQQ
#
# eHDwqleRUCw
#
# BnzY2loQ3_8
#
# 5FXbFQDMo2I
#
# -xDcHJt0iFg
#
# z5ZYBAmSnU8
#
# BJ4OjSyvVi0
#
# 3O1_3zBUKM8
#
# uUQ0k7taqpM
#
# AX9ht_WwsWg
#
# LZRT9tlSb2o
#
# zqozsDJdaiE
#
# px1BtolAEwM
#
# kXReMSwipfc
#
# TPsBJFuadkw
#
# xojlpKQz4kM
#
# tm5nPsX_zZY
#
# wXOy6Y2Rzdc
#
# cFZZbY-ybWI
#
# lmMSjhL3bMo
#
# ZzmPdn2DH3Y
#
# 8R0vhWVfWYc
#
# eMKw88VtHzE
#
# xcsBYbnHcss
#
# STay-uhKoqE
#
# siy9W90uasE
#
# 37ou8WPSynE
#
# Af7B4BuqPHs
#
# wUoBTyagI3g
#
# teMgZ5zK5AQ
#
# T_oV0m4SWYo
#
# h2OMgnoaw2U
#
# uqhhmXumYFI
#
# ITHjwFp0SNk
#
# crSuFLK4kvE
#
# bKRyHyYs7DQ
#
# Dvt7-C4a_SM
#
# YqeiphanQ_o
#
# SvgKxhLqzmQ
#
# -UZmTIkAaww
#
# 6jTtQS4_7s8
#
# QIfTnff-PL8
#
# zynkSaoadyQ
#
# rHewA7LGHAc
#
# bJgqL-Tpy7A
#
# oxtOwiEvHMQ
#
# RbR7-cZcHok
#
# RiolWw4SMd0
#
# N57UObhMp3U
#
# f5zwar2_Bs4
#
# yIlnm5uYd5M
#
# geWuQXzc7sg
#
# scPvgvnZTxE
#
# EYQplImJW8M
#
# rREf2_wEqRU
#
# lT-2GKZGqlI
#
# iTrLOIXIV8Q
#
# LooflQMsKAM
#
# Oyv1XtZ6b7k
#
# 7350BQjwpAQ
#
# Nw0_lGHAFFc
#
# O9LoE56mEHQ
#
# lYfWTE7QrqM
#
# 6Gkz57i-uwI
#
# b9XkP25U9IQ
#
# iRd3GHPtpiw
#
# JZCn1WpDZoE
#
# fjR6pvg-Q9c
#
# M2WFWnrRBiw
#
# iLYmtG_eoME
#
# soDuLJyTSRA
#
# 4YC7s2ksLC4
#
# IxGes4GBtoU
#
# lwZXjXrrXi4
#
# 7-7knsP2n5w
#
# gwr95q75CHQ
#
# nOPUEejb5Gs
#
# NR6_A0--7no
#
# gdLukA3nT9U
#
# mcv13B6ZRFQ
#
# L8AnftY8DRw
#
# jGFSEa0gFSs
#
# qaCOm_VGF7c
#
# mY-aba_JNm8
#
# 6CvbKbkURto
#
# I95Q5Vx249A
#
# OvhyzdCUu_s
#
# 7CMP2ji4EyY
#
# K1Lq0hCbm6k
#
# 2WmBa1CviYE
#
# 3nCNgPHOUaI
#
# eWZBEHCM7Og
#
# vfqUAq0giFk
#
# 1nq5i8-DQV4
#
# 1avAmSLLbSQ
#
# Qnbk-kq5itQ
#
# 8MDQ6qY61as
#
# DcLJCe2_hxM
#
# z7B-APGiq1A
#
# vNoc0iQATcI
#
# KGYHDNasNA0
#
# dWKV5rPK5rY
#
# ShXG_sQr48w
#
# DVOiKQGsBj4
#
# rXL8tLhmgKs
#
# X4ZybKAtXUo
#
# e5J4KHcnqLM
#
# kxZoROxMcI4
#
# nIE-CycFToI
#
# VxV8HvBHdKI
#
# s5Gr2Fw7sg8
#
# YF56btCNgJI
#
# Mxx7Oo5S8hs
#
# lUDsDiCWr3Q
#
# pVPuOnZYKVk
#
# ivMzsggCDmI
#
# 3T2tfLdmkg4
#
# 0_7KTNG63Xc
#
# yNrcBXH9-Fw
#
# ScyBLKhNIoI
#
# -ftjCAnjQSU
#
# ST_wzwmgMeU
#
# 7d8qD86Ju7I
#
# YUiY7YkY8nM
#
# AAID6SQ4m8o
#
# jEQ-EiZ6Nvw
#
# J6C_7gtUwdQ
#
# q78q1hWcudI
#
# 8rwvNrH0ioE
#
# 4qtO05eVBcY
#
# UKPEpFT4iHk
#
# uDoHakGplgc
#
# wUIkRJAcDFM
#
# y5cTkbiz6e4
#
# OnSMn3ysFps
#
# kY_Jz2sadZQ
#
# 1PDXaczIDvk
#
# 5yPhBTXOC9E
#
# FHXuzNa0ePY
#
# 0sqxqnHwF5o
#
# eGgv5JI0d9c
#
# 8Dkbo0gofLA
#
# f6vFtvzlocY
#
# R9iXIiAUGmg
#
# S666pWNEgKc
#
# NmWYE7pMD1I
#
# 74NmyE2iWTA
#
# KVeYL2h9Kc4
#
# ZR5SmXyArso
#
# vDFn80tRsWU
#
# qGlpHT1KhA4
#
# trkg9kgtMh4
#
# hxR4gXRvy3E
#
# 6cZimYntozw
#
# 2sLtAT5yves
#
# 09e_bcTsXgI
#
# B_7F9oV4DPI
#
# 79WP2ubSRzs
#
# 3o9mJDSqUrM
#
# WqanjOIkBIM
#
# 1u7SL9vedOo
#
# 9AK-DdV38S4
#
# 1Yp4WQRgmj4
#
# 4sgGBJKpyHE
#
# HSuy8WC6DPc
#
# CisepLb16QU
#
# fhcQvW9Dbko
#
# 1KMSM4UmYvo
#
# Jmeo3jcvz9o
#
# fpGj5Rhj0Pw
#
# li-CVUG77oo
#
# bQ2jDkEq1d4
#
# h5hDFZ-aFuI
#
# AsFfLs_Th-o
#
# hksTY-vb7Mc
#
# Kotvr-DFEX0
#
# qBeLwp5FdXw
#
# CioykjArxB4
#
# qTpt5KkgykI
#
# KORXtWDB_YA
#
# T18rMZQp5RU
#
# nskaX6zOpaE
#
# ed0nG7gLGaU
#
# TQgCXC9AReQ
#
# -NDwUwqoqRc
#
# _RN_pTo80WM
#
# KuUhhlreZDk
#
# 7KEozKXJhHs
#
# taG7k-8Soyo
#
# GwN-sfi4XCM
#
# I9b25N9UXuo
#
# IssGVbYzNBo
#
# 7jmQUZf9FJY
#
# UvhwxW9np-Q
#
# iDSLsUl2JVw
#
# kVWKP68v5iM
#
# gQtG7fL_Kco
#
# N5abEG95Pcs
#
# TDBi-36ixmk
#
# HnrVkNlHoPg
#
# DFemdMmdyfM
#
# b52H5DIVpg8
#
# 27eXSSiuy6o
#
# xbuulq4kEHQ
#
# -tCh_NDP5pk
#
# dmBa_A_heoU
#
# 6xE2XbMuXwM
#
# CRXt5Is5LRc
#
# XEr5WWti0O0
#
# vXDbPYTvloY
#
# q0i2VTQJdHo
#
# bin5l_wA88c
#
# dHQB-o3RFWs
#
# fAKEmySrhoY
#
# en688d_frPE
#
# c2tu5Z78aA0
#
# rAhODPufIu8
#
# CiZS1Saxr0E
#
# TPmeGgQ_EuI
#
# 8ROtE6o4aoU
#
# vMbbLv2qkoE
#
# JnG4uENARac
#
# 3OnLXu7ZPgs
#
# ho8arTV0A4U
#
# yLc33DYJMDQ
#
# TTfQyqvzLs8
#
# 0lwLgeqaV6M
#
# 8SwGV5dyTNI
#
# BKY9PBJH9Rc
#
# DqE5OLtNlv8
#
# w3TgZp1X6ng
#
# 2Ibs18UZ3JU
#
# jCalZPmffs4
#
# Spk9Fn0rOqU
#
# WdUFKrmkHbw
#
# 7ckBTa3vX_4
#
# t-xD4agtg3g
#
# BcdT5S1y-UI
#
# ktuNAz0J83U
#
# IWx0piNqHhw
#
# CDcbSrqh318
#
# lDp5UpDwVcc
#
# 7XSp0ZAr3WM
#
# Y6a1vvcjSSA
#
# F5sT9B3QXGA
#
# e5Wykc170TM
#
# O8HW0fjV4DQ
#
# Hr5-lngwI3c
#
# u3Mugnb4TpA
#
# cgZWiocupl4
#
# snpsCdtZNtk
#
# 5JpdO_9Nnlg
#
# s61BrZK6NQc
#
# 8NN7YX1hBdk
#
# JHL-95Y_CLs
#
# _UbXc8jqQfo
#
# I8ROI_LW9Tc
#
# 3cwpaqv_Rrg
#
# zJZSeygIIts
#
# 1KDPewdRrog
#
# EKbuLae0Tmk
#
# SGiHpR7RJlc
#
# keVMphBh87U
#
# gas9PMkSXDQ
#
# xKO7lqbuNE8
#
# r4YDXEeqBw4
#
# tBr6jF-X5_o
#
# M0OA1hkIw7M
#
# q-7MPSLuhgE
#
# 6fZxOYs670Y
#
# Hx4GhJT1a1M
#
# KjBLVo454qg
#
# MoQFd2tsBDE
#
# fMXl6GVxvqw
#
# ImFqgyB0dRA
#
# F9FqNnFhIkw
#
# e7k8w3GNTzQ
#
# YqB6kcGVU_U
#
# Jq6QcohiOiE
#
# Pp1lMoP8wnM
#
# 7jM3HHebV-g
#
# yli8JyyUB-Q
#
# _suTe1QVfEI
#
# 4CZhWAcvax0
#
# vSqwKvK_S9w
#
# yFp8ft28JD0
#
# ge8DkiNTj18
#
# rlgV4aJa-Rg
#
# K0t2YrwcECc
#
# ovumVVNsqxc
#
# GQsEPCltO68
#
# wY5QUGtXQJ0
#
# pKt2E8pYPdA
#
# Yel0gIQzcTc
#
# hr0QMQZWkfo
#
# 8Y4rKDy2PuA
#
# GttSQ0rLbYM
#
# YQQbh-lngNE
#
# dL23d8FT9V4
#
# NEeFCsodBYY
#
# Y8HQd98_KMo
#
# r9ofBe59sv4
#
# UdwcH-UTV4M
#
# _tbsvc8e77Q
#
# NCV1NtmQ6bA
#
# SeWrv7j0H9U
#
# sGxRowQhj7k
#
# RGmmrazAhXQ
#
# Oebo4SPeJhI
#
# NPLgkK5W_hQ
#
# EAt18Er8ygE
#
# nCcCjaFko58
#
# 46vfDZoP4H8
#
# NEzAW9WtUEI
#
# W-SSgWQA5MQ
#
# cW8dj50q6F0
#
# PK2Thu00nBY
#
# my2xWOR0D0o
#
# RBOtVum_gHU
#
# cB_z7jgd2Q0
#
# Czm-I86wNvI
#
# DhxPja9Xtwk
#
# JMpaHBgtE_I
#
# 0-xnRhR_jLc
#
# OBnkGQbCg9Y
#
# xexhgSqUuSg
#
# uv0eq--B7mI
#
# I_4yi2rDM34
#
# VOcizEoNg74
#
# 2l3X8Q56Q_0
#
# UxvbC2_5Uqw
#
# dKUD7GY4Znw
#
# PT9b468erYg
#
# bxQkUBq4Wns
#
# F780mOmRScY
#
# xViPMkIXI8E
#
# zcJS9qyZA_s
#
# 5gFb0s3LQqI
#
# V9RqwL1y_MU
#
# PIiLC6B2hww
#
# rQZ-OC34ptc
#
# P6MvGEOdbY4
#
# oL87vu8vP8s
#
# VChy2CcR9DI
#
# 6NrISvJiIBI
#
# khAoRP12OK0
#
# ohwLqeqekIg
#
# oQDVJ-KIIwI
#
# OBpihPVXp3g
#
# HvS0v70lZAs
#
# B3NG_qjnbXA
#
# rblWcbVs44E
#
# jwVOl_iy6e8
#
# G20EBKSxnM0
#
# MPn14U0uftQ
#
# -_0HFsQHPmw
#
# PPIc-VtMkOg
#
# DroKjgJiqPs
#
# tTkB577OWXU
#
# SOZV0zPaqVU
#
# 1pO46H3l0vo
#
# 2ODNPGfTmAQ
#
# fksFVRj8wvg
#
# EfY6L95raVA
#
# pIqycrtkzZY
#
# obJfuxvZg4k
#
# gzzIgnCLmwI
#
# Vi6OIJy4uRo
#
# 8JW2_Mh3uuI
#
# kjGUUZJgWjw
#
# KKkcWON2gQk
#
# Npc5vX2OJR0
#
# 4vRHmcxONKE
#
# nOGo75cO-e8
#
# BGnc8csuAkE
#
# FKhy4OzPyH8
#
# rnNdNFjqrIo
#
# 311ObtMzoYc
#
# R7ArT6mH1Uc
#
# ryomsN5Qulg
#
# -OSoA6TjGyE
#
# jKyqPcSNbXM
#
# tkzH3mnahfE
#
# Nf4xRcKRlJ4
#
# sZfUVyXGZpg
#
# F5a9N2JXETw
#
# LKV_8pF3lWg
#
# 3eIKrr0RqMk
#
# iR6_kBzwthw
#
# ZGVJQYNyMj4
#
# lMvdkA0f9ts
#
# 804iyFvI7s0
#
# e6Wtxb8ipwo
#
# EMPrYUvj13o
#
# 59t9_3SPS2Y
#
# 5vxeCUABGmk
#
# gy0_M-KtTLc
#
# kqYfv0NVKPM
#
# B4LeSF3FV88
#
# nDLqJ43rHPw
#
# EAbUErD9z8Y
#
# bYEJQeoO_9E
#
# HrOdLr3PLOY
#
# aWkHUSOSRnQ
#
# R2-PLrVsyuo
#
# 8xUnnxpwNI8
#
# ejhdMrwb6es
#
# Rrcc0KMly6s
#
# OoJ5gYW-A78
#
# UKth1LiyJ2A
#
# -gH8XYzVt9M
#
# sY-gCfnc3g0
#
# G4UxFqqInCc
#
# PX-3AZ0aVmA
#
# 4aemfxuIFFk
#
# ehom69ZEhnY
#
# vyeCmeFXDH8
#
# KnKCcS1RkOU
#
# EzX9LzRmuyQ
#
# ko4F3XdFmbE
#
# QlE_50MiBns
#
# 4p1Yaip-rL4
#
# 21U5xTK_sKc
#
# e3ysxElN9ng
#
# 5E5Cf4uQVh8
#
# w5b93DESzK4
#
# yLdzbBzqJKg
#
# QNRBAbpR68I
#
# uCWzatH9-tY
#
# xhoasn9katY
#
# ZRuTqBWjqAI
#
# fODAzXihf_s
#
# H3ZkP05bjjQ
#
# sIZ_5Qez9Ts
#
# ZLqAnephW_c
#
# uSuey0XJgwU
#
# FgRvlaQMxZE
#
# f9j8qazQHZo
#
# XEmonJqpTjM
#
# yEKZylAdf-Q
#
# lLnpVeO58Lk
#
# 8hDhgdJVXEM
#
# cdQxR5LR5BA
#
# r-R_-x6RqWw
#
# lGfgPyDprEQ
#
# TIWIcSebCSg
#
# WhJR_7qcEMY
#
# lY7FfngF7ac
#
# gTBD1fmr8Zs
#
# 9qOW2wTgq7c
#
# JVhnb1FBrdo
#
# V96-cB6nVbY
#
# cjA-sMNnV0Q
#
# HshneUR11Sc
#
# EOkMiFu_9u8
#
# V_hOzE_FGqQ
#
# -kXDfwFeBbE
#
# kHMdS72dIoM
#
# fhVGwk_QKS0
#
# XuG1bKc64So
#
# 2mEGwgSTuxo
#
# CxgbnWrxyJs
#
# NhCB6JbTnPw
#
# Stn5G1Lw71E
#
# Azt6mpTUD_U
#
# JoWv4MBLL_A
#
# YU9z-9SEb7g
#
# Mh3jByj4Kt0
#
# -q4Cjwk_Z4Q
#
# x5X15-1GnFg
#
# EE1Ih_ZENNE
#
# CVObYlGebLU
#
# 0nc6KGIlG80
#
# 2aLMcoP0IPI
#
# TRrEMkufOeY
#
# qVRHZ0C7DM4
#
# _mipFoYb4N0
#
# GNCJP-ug3Wg
#
# VM4b-hTLHXE
#
# kEXrum7YSB4
#
# M3JZiC9_-Ak
#
# opbRcI_5L-o
#
# M6I-rXzBVDQ
#
# qM9qtQJZP24
#
# 4tIne8qNxBs
#
# 73sEycmhXGc
#
# tW2lsiaQkyA
#
# 48t_IkNFqWs
#
# FBomn-JM3ZI
#
# b48UnC6Hmdk
#
# rsKiJYUgZcE
#
# Fb2DCIFo7rc
#
# k7nfIjZ6BvI
#
# RsBg_WOksYc
#
# rjhDW5HWW6w
#
# ifYaCQuVknc
#
# dNGxJhQd-0U
#
# gjI9Bs8f9gM
#
# eiIYU9TqaNM
#
# J8D98ePu43g
#
# RASbYXDeyj8
#
# bAvyBnhnzBg
#
# K98wx8xV0Uc
#
# 7cflV_5M-ig
#
# j_uhaq-ZlJc
#
# PgO36TbA3KI
#
# rCCY9Ax9-3A
#
# tjPD4JMT67M
#
# xIjb533we4I
#
# 7NnXrg1nZP0
#
# UZJPvQNi9Ro
#
# N2iOvii-594
#
# 0J5QBpPddo4
#
# uHR0qIdb9h8
#
# ok7kbM38NlM
#
# IxHVc6pJg44
#
# JytHDmBgbpw
#
# 3PYkNlMGrt0
#
# lQZuN_qXJWs
#
# 7BL6bRUnR0U
#
# BZE8cdiubFI
#
# Km_vqlQMcVg
#
# PBrGuew88xA
#
# eHhPDRaTraU
#
# wB9Ewmqfn4E
#
# ckBNnd9-bDk
#
# obwagCfaEYo
#
# 3vWZl83MinA
#
# XaE45YnXuys
#
# oG6Oo1s9fJU
#
# lqxhz_Nn7oA
#
# bXBx9pzZom0
#
# sZ9_XyEmzq8
#
# NCdUNey3NsY
#
# lW9ZuFCvRxs
#
# hovIk7Ifgzs
#
# xyMaJLJkFBQ
#
# n_l5SmtODB4
#
# uQoe9U0qabw
#
# O556Ag6O18Q
#
# tkAy8ngyRsY
#
# lgt-G4qVxE4
#
# 7glsrtePP0Y
#
# 6jJPBrOswZA
#
# vqzwmtX8qhw
#
# eimWKbVd7lM
#
# ifDJAU02_vs
#
# Iz_LPSzVX1c
#
# g8JJ1QkYvG0
#
# og0xm-xjRyk
#
# nuD85sah5IQ
#
# cfWKse-pCm0
#
# Hh-Kmq6qZrQ
#
# -5UeBG_VFGI
#
# yKJnDgoe2x4
#
# v92h_YASGEw
#
# cQKCYCXQqsg
#
# zU8hf0frNEE
#
# Ob6AyMVYMEo
#
# vT8aTBSLha8
#
# sB5szE8eUI4
#
# pynmap7sQpU
#
# EESXC93Jp-o
#
# RuNQRbHaMb4
#
# U8ItUtx4nQg
#
# k67DWPNLQHc
#
# BJWZqNY1abY
#
# rS6G7ClCgsU
#
# OV6gmnQpCwk
#
# FaS7am3LXvc
#
# -BH03M0jZVQ
#
# OORLlvUhDpI
#
# NasJ-x4yqeY
#
# qED3KjYKcAI
#
# WojoheaWbWg
#
# WkFDFDwwink
#
# lMDt14Izivs
#
# kua5sZZKTyA
#
# VSm0njml7TU
#
# a9XEE-dxOts
#
# bXsyxIcb1wc
#
# Xo2uUq0W164
#
# TX5WbfWW-yQ
#
# dtbVcP6CNn0
#
# mO4NhMh8-Ik
#
# QHkVnOLuOkE
#
# GH2ujXcDgI0
#
# md5pISvsnxE
#
# -QIK-27c7QE
#
# UzDE2s7gy5Y
#
# j4d9N2lxU4E
#
# 6tjEB8zje_o
#
# Ux8VALiTdVM
#
# nEKAVjbOTk8
#
# sEN-QuibGpk
#
# 73_bJBdTuQw
#
# JdIbpKBiFPk
#
# It_5i-EIbLk
#
# IbNqob1kLOE
#
# 2NAu6g9n4LY
#
# 1Fzoohp8bog
#
# hOSaEFnliCk
#
# 8PVC5WDam7M
#
# AlTazd6bs-s
#
# PYaPeOiQBR8
#
# 3SzLTH42tHQ
#
# eLKx4y9C9xk
#
# gev9FRnogl0
#
# bgeJPha3ECU
#
# Cd1I7vxQh-w
#
# b0X5nROhsMg
#
# oigZVh2gImk
#
# WoIuP-ZABhc
#
# X5KNvr8Iw6o
#
# 9VjyUnZR7bY
#
# ucHH1U8hero
#
# tgFfbKzF808
#
# uX7JtCoBiHU
#
# BEKRiLD3RZc
#
# hzRdZX1jqbg
#
# CBi9CgRqwiM
#
# CJBwgnjSkKg
#
# 7nIuwuK6HFI
#
# 3T7aLERDyJg
#
# tTKhcyHT9Vw
#
# i7Y1Cbp86wo
#
# EyfWDl063Uc
#
# GL7YYgzaLnU
#
# Ap8FAJDGin4
#
# Cg68Cq3qdKA
#
# YpqjWlIsA0o
#
# CrB33pgu2LI
#
# gx5bCQZmoOU
#
# x9V5QJDGxJc
#
# hRvJ31HpWY4
#
# tZY-iWc242c
#
# QvonGqyRlY8
#
# M6dO8VAkXu0
#
# XSjrsJmeD8I
#
# Z7Ag4pBdIRg
#
# JsQJWD_Kok4
#
# JQfRlj_4CA0
#
# F1fVqRPoEEU
#
# BzOWEMChcVA
#
# yRcGEgNpZUU
#
# cgzA2IZV5Yw
#
# EGVVmN5_ieM
#
# baCCiu2B3vo
#
# 16wYrHXEezc
#
# nvWVbXUdsDE
#
# ad98E5-imWM
#
# xNzLH5jc6eg
#
# i6rLNIMgV5s
#
# H4-KtIw7dMc
#
# f62UNFKT9fQ
#
# BettKYSZDac
#
# PoNT6qjjbos
#
# 5hwiH4K44cg
#
# bLQs_T_hUQE
#
# -c_05Kee2HE
#
# ey2H0BvasNg
#
# bgOTb4Hh2ww
#
# 63g1Gs89-UA
#
# nyDqRIz0qYw
#
# lr5KRCQZ_qo
#
# n_B2Bl1QkMU
#
# aky0ImtZ_5c
#
# YrbseS20cF0
#
# f_B7Om968zw
#
# OwWaLf-IXhM
#
# kplHx-if3HU
#
# NepPfK7qGbU
#
# CBLvjyfLYqA
#
# 6fVZFqd7zZw
#
# 8BHXcV0Fgcs
#
# 3CtB15yqdvk
#
# dly_fRzRVV8
#
# 3UYvRz4y0fc
#
# N4IdIzDknUc
#
# jx0o1mesivQ
#
# kzrCZlDduJw
#
# FJlkylB-e0Y
#
# CfqKVrfyyLU
#
# AuAq-pbX1rM
#
# pGoHA1La1fA
#
# -Uzpk0ckwCI
#
# 3aLrBsKOsRM
#
# 2KNKd6mT6MA
#
# aiChD-2F4ao
#
# m9CpHp9MmXo
#
# v1lymOZcIKw
#
# k5WM_NZNeWM
#
# yX0hhXCeImo
#
# Bzrv7s8zRD4
#
# qENw_6CcR3c
#
# Mq-MZUVY0RQ
#
# P01b-Vg172Y
#
# hyNY4zS0cRs
#
# 7AHowtliIQg
#
# dyitNm62V-Y
#
# RpH0WGG3B7Y
#
# r6brnVWPczY
#
# zKmQksstvBY
#
# 8egqIvTqfy4
#
# S0x_6VHLwyI
#
# HmXMhG23hRQ
#
# arBN4kmJOS4
#
# ZceAqJdDln4
#
# twDLkzfjDkA
#
# 7N_YxVMbi_o
#
# I77IjWJqIv0
#
# CXOJaQsBmd0
#
# hHEBoulrn3I
#
# BMlXC4wnvh4
#
# N07Gj4jueh8
#
# vHRi4JP_KUI
#
# 55BmnLBFY0I
#
# _PROTLi_Ybg
#
# kChFMhfwCc4
#
# Y3LogIrMpIw
#
# 8I3ajR4pvEw
#
# iPp8SCx8W_U
#
# DellRPCOrTU
#
# ABfMPJcz9I0
#
# JWLtjmHMJwE
#
# ae_0txTWTWM
#
# NDyvOA3YoOo
#
# 9juoUD_LDTQ
#
# JE0_xMY7Mjo
#
# duXu34mKXT0
#
# rw8g4G6CMkE
#
# 98o2TO1ZUKA
#
# U4LQlauIbBU
#
# Npw3ixiHG0w
#
# oNwXr2wb_98
#
# vnXFhREqHlI
#
# DU9pc_5RPEg
#
# 6l0GjT3G8CY
#
# mxCkI1-iN3w
#
# 4p-46y0UZ0w
#
# 87eG-fQIu14
#
# Nhm0i5rzG8s
#
# k-yhs7GYgmA
#
# ahj8x0HdFvM
#
# dtf2k5nwxNg
#
# ZpPW3oleY4A
#
# pS3xEqLqwhU
#
# YUFK-b7i8Z4
#
# zm0XnKxCgsA
#
# Rx_mNYcTeRc
#
# uAHvBelvu1k
#
# p886-QNzTj4
#
# KddQMVMiLrc
#
# g8OoHJr7Cl0
#
# H-kJWekS8Nk
#
# sdE6ngjEg_o
#
# endT4d-8sU4
#
# pCQ-rsv-5G0
#
# rwDGSYS2LFc
#
# aF3wUjLCJJ4
#
# _EHzWg89GpQ
#
# lIX4acEYwi8
#
# YTT3gZBq38A
#
# PhoxHtER6jU
#
# PYhbPV7MahE
#
# fiAcBL2tmKU
#
# i-6KlsmAPKg
#
# ASXt5yJn7BY
#
# iFpue-ql3zs
#
# QS2_Mc96uns
#
# Nap0_qR_usM
#
# fIq1FiZN_4k
#
# zmwhxz2lNP4
#
# 3L4CH6P9MFo
#
# pM0l9X6Z_yU
#
# zpf6Iu8EbLk
#
# jcteE6aCwXg
#
# PJbBZ3JfgmU
#
# MqZFnC5CYt0
#
# 3Ua5HgklkYs
#
# Sqz5429n86I
#
# gREtCBUaOk4
#
# SGmUz4gWwQE
#
# qfnKzfBsVF4
#
# 0pskSD1xAuY
#
# cOxl1t8ZCRc
#
# 3ZzQ08FuORg
#
# mQCMt6wpADk
#
# oFx-ck6waHY
#
# _a95JN7C0Bw
#
# RWHsPHqY2eI
#
# o8ZnAhvJ_Rc
#
# akW4wqRHUzA
#
# fhJK7jn0KhI
#
# bphlRjGstAE
#
# c7UE0BXmCXE
#
# MsAO8eY-LMo
#
# TQyEqsy73tc
#
# P-ptj7ObAfk
#
# rkk-LVpetzA
#
# LDLfAGN1voE
#
# _lCI0F6F9Ac
#
# A77T9pJIxIA
#
# Xwvh_o0u2D4
#
# I7boXrUFnW4
#
# ukhs5ZsKzc8
#
# YZjDXMfQqWA
#
# dkVmYHx5tI4
#
# eMVdaNYxkCs
#
# y4xtf5Y677g
#
# qEDjogPGSlE
#
# iDMpFbDOu-8
#
# EoSNnbji-Hs
#
# mPluNqI6XUs
#
# fzE47uUVhoA
#
# yplq_vMyxPQ
#
# i_X5Hfhtvfw
#
# JnW4zYHb7wQ
#
# S5gfPVT8Vyc
#
# TTz2oFN-r68
#
# ehub8zPYU_U
#
# TbFwXtznzmI
#
# b05ZfunJXx4
#
# ZeA8sBeIr70
#
# p8oDYIyEyYA
#
# o1mjCY33tUs
#
# tHIZoJapK88
#
# jBKN4A4annA
#
# 8VaWVgIZOus
#
# YkcAUnzt1jQ
#
# GsUk1GTxoz0
#
# 1hZTDmoeJf8
#
# _bpI56Q5nww
#
# vcybNM_vNwo
#
# yKUfButCTsY
#
# 2eVQmW9-zUE
#
# TD7sBUigDIU
#
# qpZ6PzRQxPU
#
# GTu2l_0zkUk
#
# r4Xstoq18gA
#
# qBC_urz-uO8
#
# zHIE6J11MB8
#
# swc1J-BX8CI
#
# l7uBMo2cib4
#
# _PKAg0_uC0s
#
# qJmYN5S9Zaw
#
# E28Pb09yu3A
#
# EOilfXpzCm0
#
# QbgyC59aruM
#
# QwzqYhrizD0
#
# yWazW7MjkpY
#
# knhGL6ei5bM
#
# UKz35nHPODI
#
# Mo0S84c56WQ
#
# G2wLVzDvlzQ
#
# 4LB0j51Wiyk
#
# MqzSPR0C2o0
#
# wJm9r82Mop8
#
# TgOa2N-zInQ
#
# JBdxV9aGnfo
#
# h6jfc9xknTk
#
# fQbAE606jwU
#
# BELUklUYJjY
#
# TFnEL2CmavU
#
# 2UM4tCeeVVg
#
# 2OM4Gb0rRlI
#
# FM7ycl8TH0g
#
# 8nuIR_73nLM
#
# Mwh2fymEOsQ
#
# uj7OUcO-37M
#
# y3uO9pX9Ki0
#
# s4cUQy8u-k8
#
# 67TyGgIClR8
#
# -BhIkr5if5s
#
# RegR9tWqzHw
#
# uy6wi7MRwP8
#
# 6nGXyEl6gzw
#
# xjlAQP9s_fE
#
# EDlFsB3TKzA
#
# QPX0lneQWkA
#
# 7SHNyXtkSP8
#
# rEW9iM9bz8k
#
# VoTT_9qnqDA
#
# S80fIMNihro
#
# hWfosFf9xkY
#
# rUEV7kw_lfE
#
# 6qdzX31q2Nk
#
# GYxggtZberM
#
# Tg1Ih6ETjzI
#
# qXktFkCZTh0
#
# CBjlMQcxdCY
#
# Uo_Ir94CkWw
#
# PPMCI9cB1Vk
#
# asi4ppK2H38
#
# 7jFfuje2pkw
#
# n2-KMSd5-X4
#
# njyMLD76DRU
#
# jJea9rbFlKI
#
# 96q6Ogu4aqY
#
# 9_JhSEqZt_o
#
# AFkW8TF8dHI
#
# 27T6K8Y2e1k
#
# gnk_urTsMz4
#
# SRDfJYzUFuE
#
# VbBbx1oBN7w
#
# kK2gNJWaRNY
#
# m_GU_75CxXg
#
# -bsgxU_sqn0
#
# FISDVunIZfI
#
# mp23FvysnxI
#
# R1arkPXqSTA
#
# GXOPpSQebLs
#
# 6ZPiwZw6dpU
#
# ROIS8pmo0m8
#
# tpHYw8VmOCI
#
# lPonNzyIm2k
#
# Bfv0zIBSzBM
#
# q8_q3Frkkrk
#
# GmkuSMTcCnc
#
# Ktons-KIqio
#
# ylSSe8MVkNA
#
# alGAtjSVg-U
#
# pN74A1IGegI
#
# XUemE5wiwrw
#
# CQBYZkPXT-c
#
# VmDvODzRutY
#
# B3Y-_VJbbsg
#
# hi2SzT1glzQ
#
# 4EHgUSMjG_M
#
# Gc6rgbj_E0A
#
# PuKW8KV3dic
#
# YQCO86u-Q-0
#
# lXj-eC_moFc
#
# LvHA51q11kM
#
# XMGeQhstcsQ
#
# D3mJxlN_3OM
#
# kimwdK-jvYk
#
# oB613vPst6E
#
# wJ9pVqGmoD4
#
# kDmOOj5Y0DI
#
# Ep7KCjE3eWA
#
# TgU5xujCwF8
#
# 8zRy02Wl1JA
#
# qZftJXa8Bss
#
# _AEA6-kK-CY
#
# JpbXwjdmbx0
#
# OEmCh5EK2mc
#
# SBvwYGXnpts
#
# cHQn7ZVqQcg
#
# iFc0RGXZeNE
#
# HEJHOj7GBBc
#
# Yq8Yoocmxtg
#
# XRl6Jh6QHos
#
# 2_hL-LMzokE
#
# dAJ52iRDifs
#
# mSXNodTt6bw
#
# 37TQjl40Idw
#
# 9xIXGNop7GA
#
# lTLVAGFmbRw
#
# U7UO_mltuqw
#
# WL4wDxejzFc
#
# FhagW8fcR4I
#
# gOtfJ151ue4
#
# Bn3NewE2Cww
#
# YWCsBJnXvhk
#
# y-OEtyRIWSg
#
# qFkLwku4maI
#
# p6ogJbqWFQ0
#
# 9VFUcx4AfOA
#
# ulSRJhkfDmo
#
# LI1R23Vc8r0
#
# WZwv1dnJDsw
#
# rl8LM-hsKiw
#
# N7VczvnLejw
#
# yP1RLGmR-N8
#
# 8w91KkZqY9E
#
# 9vwO-gplFM4
#
# FtpdQ5QvGYQ
#
# luNIccSIwRg
#
# 8q-Yd1x4dkk
#
# DTDVMjjz1k8
#
# mZnthnLIcA4
#
# lXxpYIshRwY
#
# DJHjD9FFsrM
#
# uMj6-ZiatZM
#
# RxchoP538xM
#
# lZ8Ru-hAg9s
#
# TYHqV4AM6iI
#
# 58RGBszWZ6w
#
# yU3g123KdPQ
#
# Bhg-Gw953b0
#
# ENlVcyyrcBE
#
# YM5jXznLcyU
#
# 0djMgxHwLDs
#
# luAleZrZWYE
#
# c1bfuNvNRjk
#
# dX_cSKJO_A0
#
# hYK79U0jCaY
#
# Lw10A8jDxXY
#
# PzdC10pcWFQ
#
# TGG1bsxl8r8
#
# u3xqsdEaPbY
#
# VhoXa9rMwi0
#
# J2XoIhXMiEo
#
# xylOenvIbbE
#
# 7Waz9o9a3QU
#
# hBr2geGVd_U
#
# wfBIQAEd_KM
#
# Hd5c72LAumI
#
# pJB_K_g8rRE
#
# QHx2G-b8YdA
#
# CgRao2RWR6I
#
# bbtOwbM3OtU
#
# qefGeu40SUY
#
# SAWrASztfEU
#
# XKKHn_bl9x4
#
# bhDQ3gFMX8o
#
# NEPiaf9SGBU
#
# VLxkNj4tox0
#
# nGJE-YCs-_M
#
# kss-3GQxoXg
#
# dJNZZKNfRfs
#
# FkEJh_mRrw4
#
# yeSVbWZQzek
#
# 63ig-buaGqE
#
# Uhu5ST3SJ1E
#
# OVNd6SGJk_c
#
# n-yRbm4wPFs
#
# 6NC9_aYk2hM
#
# Ws2D8a2uin0
#
# 6iHAy91YWag
#
# J9t2AJuM5fc
#
# JSm1Iel8Llk
#
# -d2f3GOQBqY
#
# fnXi_1UAnsY
#
# 6Dq4boXu5Sg
#
# v7xERN4W4qU
#
# H9osJx8tScY
#
# wAep4wf8LCo
#
# yrnoR7sHG6Q
#
# Gxl43QVBkXI
#
# 7zpM-4V2ECI
#
# _stmyle1Vg8
#
# ni4bfoaCV2s
#
# 7TqkGqPhO5U
#
# M-dwuBz_6uU
#
# 3QuOZE6Ur5k
#
# cfn34Rn8i-4
#
# ud5u_gtCoKo
#
# 9ZoKDnzmATk
#
# e2epHH3R_ps
#
# 5CEXcm5mHXo
#
# M8148nL9ME8
#
# xSsNX76QeC4
#
# wzchjL--pYg
#
# f10c9Gco10k
#
# 9TdBjL-Igo8
#
# _-tU7214aHM
#
# ykwNKJQbfeo
#
# 5JsOf8kTNQw
#
# 7pyRXXmpteQ
#
# fDGHfWNUJLw
#
# wbdeFkVoFjg
#
# NQYFUA4Z01I
#
# c4tAV5rHrhg
#
# gNnwEkVDSTU
#
# GvVDo5ozAGs
#
# Y2WfCEaqlkw
#
# 5E4jE3es0ak
#
# t9EOuzCjtSE
#
# FNCJ5rF2cuQ
#
# -MXpAQxa2IQ
#
# FUoDu0kN3M8
#
# i4j6snK4ZvY
#
# TU2k_D__zO4
#
# JCC3y-NLxMY
#
# Tm-TckF3xPc
#
# PpPvaHMH-D8
#
# LndivqTvMBw
#
# tZoIDhyhDSc
#
# H8QAlrQEC5s
#
# SzlkfnRKlvc
#
# GggMi56OZeA
#
# IM3JKi6xBTw
#
# erO0CYak7Pw
#
# E0AFbHfRgxY
#
# jQkDzHR1Jy4
#
# 1rTtRc_PAtM
#
# hppE_ZVI5gA
#
# <_io.TextIOWrapper name='/content/drive/MyDrive/scraping_data_01.txt' mode='r' encoding='UTF-8'>
# vtPK0feHhSs
#
# XEHwvfdxAVQ
#
# qvtg3OpZ8B4
#
# KIJRzhdfYYs
#
# Su3ypPXuEBk
#
# ccFHiwDwaTc
#
# F_8kd51DStY
#
# oxoZ2juHgmY
#
# cp7XabJw6Ho
#
# Iyb2M8-e74A
#
# V-xRLz6FXgM
#
# HvriWrmCDn4
#
# xNV1WMh51fM
#
# R3qeKsJ1IFQ
#
# BOeiYIiUgXk
#
# KSqb1XTt7JY
#
# DQJhxK_RYpk
#
# 9fcZUJdz3fk
#
# PPTaWFYZg68
#
# rSYF-ljJQNk
#
# IH8K4DGF6CE
#
# 2O530z40KLU
#
# 3dF7tpHnqro
#
# rfnbBERJeNA
#
# dfvkCDtiAmU
#
# SCLhqb64PI0
#
# kJRQowHhdD4
#
# Ytj9W1RZQCM
#
# zKgBmcIp8qU
#
# o5GF3-p9xYc
#
# XlqGtAIKD08
#
# kkGbmgLFVmY
#
# OquX0kY2M8M
#
# b2MB1p3PPtM
#
# syqLgFudBv8
#
# yQgskNESGd4
#
# 7Plr94eT-sg
#
# 1bayWK5f4MM
#
# FOahBJEah9E
#
# kcXpaA6ZxcQ
#
# Hn0Tfb2dPsg
#
# CauAzHBII_4
#
# Lk6QXspxCtU
#
# RFV4RMjIIDs
#
# 0pZAOwSLaYk
#
# MO0Hxfj3Uhk
#
# n6Pnzi6r9NU
#
# BQTiTD3k4LQ
#
# Ct1I6Gjeio0
#
# IpbppGyJmuQ
#
# ERbU7FsKB4w
#
# m1BmNp0e_lI
#
# ZvFv6hhuccQ
#
# xIrknhyHl9A
#
# K5vvVKb99RY
#
# 08x0-_qrvvs
#
# Gxsoj8aIRao
#
# -B9yQJnjayE
#
# gcE2phoechY
#
# i4JvIJnCGDc
#
# TFTJ7zYo6zo
#
# HeJ89HG5II0
#
# EA-n-LfRJWY
#
# feS4AsPD6fE
#
# 0gsvO8vGpek
#
# vB9enDwuJlg
#
# EVn8U-0TsZ4
#
# Ue4DD33Ynjc
#
# GYaN4aytG5I
#
# m-gxk2BSm1A
#
# 3equ2Gy17Hw
#
# t9L4UqXr4ok
#
# -gzD558fxiI
#
# lkVjbBuMca0
#
# TT-g3gWTFbI
#
# mfZIocNt40U
#
# GrdOD8kmD0g
#
# kudu1cHIy_k
#
# X7HqiyigCvo
#
# Zf4siyVEm6E
#
# QobJQmTOHk0
#
# QFNkUtGs9lU
#
# C08YT0Rlt3U
#
# CarMzZrIfVg
#
# FfWcfnzaA7Q
#
# cBOPmdpDhZI
#
# k5eTy-5Y0Y0
#
# s5WPwSouofQ
#
# Ekc7AqXXR1U
#
# oa5erVqj3BU
#
# EjWp1aGuZ2E
#
# BT7MBSejhW0
#
# 9VKXUu0USd8
#
# jkhn6l8SotI
#
# nzHp5Ymy-9E
#
# DKucbEyc_aQ
#
# Kwl0KNMFMzE
#
# dKXAl-f4gR8
#
# ONR4UUvJ7Ik
#
# sfpvvrOO7TE
#
# 9mjn4NTMdGg
#
# cGzqp7DFEek
#
# MwSOyteBuBE
#
# 2_V-YUZv7MM
#
# AVPrUXKJmWw
#
# d6SAlbolcmo
#
# AkixwO2O6jQ
#
# qYX-b7wkV0c
#
# C7Rz8zdveNc
#
# BjIrbZWhUhE
#
# mv4ArZoyhho
#
# nJXQmI27Vzg
#
# Z0cyw4m6v0s
#
# nC2xN4CaB9A
#
# lU2Jve0mI9g
#
# d65JGEwN6M4
#
# FEgyeSa-2N0
#
# SvYfchKkdNw
#
# CJTw-8_6TvM
#
# un9vfKLr49g
#
# UVPjcl6HQ1k
#
# WmrmShrynhY
#
# BV_DVcQM56s
#
# 6YgL231h7Rw
#
# 77MxPZvsYhI
#
# _2cR-XfCHqQ
#
# Ma2ywEw_6c0
#
# IIgS13NkwkY
#
# JWhznotIxJg
#
# 693ttyNImqM
#
# Imr_2yuBpC8
#
# ydaaQLJICTQ
#
# duGoR-b7mu0
#
# i7wa05YbyGw
#
# oNnBSC_UPt0
#
# wUZ1_mQKWMY
#
# b7YEY40uEhA
#
# T8wANObG0LQ
#
# elUMLR2Niy0
#
# 00k7OllBV1c
#
# tD_junwovh4
#
# SFIhEpDA4I8
#
# w_MP4ZuBcxs
#
# sgLg9P_iZiU
#
# msohs2YjS0I
#
# 3gC48ufZ92k
#
# H2UVpf1dqoQ
#
# 7KjFBfBZRQQ
#
# AJNz2tfOyqI
#
# 7kyG4gQbHCA
#
# ghGo-1mxTmc
#
# x3IXMdED6Jo
#
# rlErwHuOqgk
#
# BsZyQRSmThQ
#
# RoWO7inTSIs
#
# CCmYGV_YUQM
#
# t5R3l7mETbw
#
# u5kEc2MWtHY
#
# x9wU82Gj3IA
#
# ge88HqmBHt8
#
# W_l0beC7FAQ
#
# dOrssGD7WPE
#
# KsTxggrJy30
#
# 2hrihX8-Fss
#
# MRf8bNI8TDo
#
# 4J1HdMvr3vg
#
# psIG8nLyQPU
#
# jVSevhXkdzA
#
# ux_OwKolRkA
#
# b6BQDq40h5A
#
# ZuKA5X6sNkk
#
# dZRPsQ9h1Io
#
# qGX6kDznsGk
#
# 7FIN7pJ4TsE
#
# BgIuPfOZhl0
#
# h3hT8iO7ncQ
#
# JwpOeRWt8uQ
#
# Ny59RtYqQfg
#
# HruIcDteokY
#
# UVCmktFx2aI
#
# CBzNjv-c_vI
#
# VA0F7tq-fFM
#
# BVPGb-hRRI4
#
# SDUVjn-r_Jk
#
# 5jhYfCkmPVo
#
# 6_iYJGPrp0Y
#
# fOUtvHxPnK0
#
# Xum-yN_5zXc
#
# JefyNErkGcE
#
# nTzkLbVIa-8
#
# 6j8I1plkBEE
#
# POqNgMlhOH0
#
# yYGB5JXHqEU
#
# ZXjodAGbPbk
#
# MihqpB9TyzY
#
# bXh9DXk72Tw
#
# bJjBPRtGWIY
#
# WDScPm8rxuY
#
# IIrDjR4DM8g
#
# d-J6H3ko3G0
#
# WwMdlJorWSY
#
# SEk7ixma7PU
#
# fX0HWPs9ddQ
#
# j7jtf77F2dE
#
# 4tyuwWAbkwQ
#
# MvIiJnCTxwc
#
# FYu4XSFxKXE
#
# y0LH72oob2Q
#
# MGnAQfYmV8U
#
# UBpDaSMN_es
#
# 1AZrSJfK9V4
#
# NZR8HyNX-lg
#
# zu0x2In6UAM
#
# mRXJOOxeVIE
#
# JJ_Htfkmopk
#
# I6dMgumD1G8
#
# TotsEqykfbk
#
# -syNZDCua9U
#
# aAhwWrcyLTQ
#
# JLXQPuWP9yc
#
# vn_DE3gtaag
#
# PURcwTlw9h0
#
# B1_13cunxo0
#
# FWxNYXmHmKw
#
# 2FlpG-4kljk
#
# eLYoMGy_FdQ
#
# 2TrpZkHVWjo
#
# l2R-gI6IldY
#
# 3huBeqsxvQA
#
# 86jDs-9svgE
#
# FjhnvSWMoKM
#
# edKZVdF1ydY
#
# v6u3ffG3wL0
#
# YEAfY21Agdw
#
# -EQcnHacrbQ
#
# Jc6JfEd7_Bk
#
# vlRUT4LZmTg
#
# 4E8eHhvBC8A
#
# P6BamWphIPA
#
# i9i0CXKvqXE
#
# zRjtohc1cq8
#
# hdhU7fXPaxE
#
# T9mml0VaoYc
#
# hI1pdGXCPAY
#
# ITntRZ9FwhA
#
# _7qkK-oKB7g
#
# i5gVIwwD2xg
#
# F1JudLNKu44
#
# xulD70Av2kw
#
# eFwlw3d5T1c
#
# O7NAkG6SfGQ
#
# oyZJh9meuOM
#
# e5Z0LR9poDo
#
# l-_fSCvJ52o
#
# Hr9KVpSnpc0
#
# gksUcGUfRy8
#
# iBoftgCvtZU
#
# Ice6PNs75nI
#
# rrx8KWVfm2g
#
# 4Xt0uXeFmAY
#
# qiI4XNUoiyg
#
# AqutLh-4O4A
#
# Vo36hr3darg
#
# -EeRy16WUK4
#
# YgpFPfsBzaU
#
# KlQrTUdNOWA
#
# i6i4p4GEMzI
#
# mdmMZB9AFFo
#
# VaO6Iq1owss
#
# sArIX_gYFyw
#
# G9BMlVyUhBU
#
# LFyC-aWEr-E
#
# JfB9J1cgm-w
#
# alGU_gYQWLE
#
# JDjMv7R4uAw
#
# v5yVEjWMt0A
#
# IkXGkc8357I
#
# RkH70UzGYLQ
#
# Ss8Zbn_xOos
#
# za2PlnFjt08
#
# gFucT33X4kI
#
# zZQCyZDpOws
#
# 2Tt0qcjDyTI
#
# UU_6gURS9UQ
#
# ZPLEpV0vzck
#
# 82CTx08Zw70
#
# 7UiysvcPN-U
#
# UYbdWK3JO1Q
#
# _fwSoNt7AbA
#
# i8Uzxp7xbLA
#
# q659As_EwiI
#
# nKt7HMXc-Vo
#
# iScKTD6IOYI
#
# yIw5K52qDzo
#
# X6pyLl1Qjgc
#
# uOcFGCPTUkg
#
# EKpVpXasVUY
#
# DqV8Q0f042w
#
# O60-Lg1B1Ls
#
# kWkJVeEVDeo
#
# OhX7tgjHO2k
#
# 2d7kUySWXHw
#
# f7y0cCuAy_4
#
# UM2s3S0iBEY
#
# l5j4dAKPeSo
#
# M2GKWufbYJI
#
# LEL6JYrtA5Q
#
# YPbNuhYNTOM
#
# 2KE6FIhYrA0
#
# 3b4jgHGilTA
#
# f7fF-xxFiYg
#
# -kPu3i8TBYI
#
# z8j9yKtMqTo
#
# iX7ViCkaVIU
#
# PTvcdieE6Jw
#
# urlmyC2xRYQ
#
# kW0ZQSKXtpI
#
# 3OCzDJHlDYE
#
# ESN1UCgBuTo
#
# fDM5XUGnxDI
#
# 8R4RJftWKn8
#
# UVHjo0Y6IPc
#
# rUD2UceCRz4
#
# wZRZvp6Di-o
#
# RmXvn1kvfpA
#
# lG2o6Nziaq8
#
# oZ5dYfS34SM
#
# S9jYVnDyNrg
#
# GMbVvNFIQA4
#
# hHfGsRtq5ag
#
# zXtHnQj3uRQ
#
# _1RT46cl5nw
#
# YmWdj0yO-No
#
# yMoQpGavYso
#
# IkJJJVagXjk
#
# dziyMrfw5KM
#
# WnYWwjEZB8w
#
# QHIUO7aj2xc
#
# P56mDhUwd7w
#
# yyqZEUsWeyY
#
# zuDWUKWfQMo
#
# 0Ii3cyTYQbg
#
# Im1amcEsYag
#
# 89MGTj3YweQ
#
# kN-deCsvgFU
#
# a_jXBTQXGlw
#
# ZQ4QRThVQWA
#
# ebn_CcTn1ls
#
# S7zeH9BG47c
#
# Am8g-U4v8fs
#
# iMHOLkTG880
#
# 2it7KyU8Dn8
#
# VnJuG00cTcI
#
# d88obI-DFZ0
#
# geOlwBst8aY
#
# buZcn2v1W_8
#
# ApI3zMHdEdI
#
# x8qNHtUdsHs
#
# iVIX9wyDrb4
#
# z_GzprqEtmA
#
# jsPMz3VEqnk
#
# zWGEVNIFqBs
#
# E10t-gpey9s
#
# KX572z7czvA
#
# UMn0tJHCenE
#
# STlaCpqSzg8
#
# AFURgZDpyIA
#
# OnxIjPyzd4M
#
# B0rY-qQ6UkE
#
# MMJqLjMuLDE
#
# 4umw14drxjs
#
# TLztCmPJkPQ
#
# 9Co6r7bWVtQ
#
# EanzB-5sQSs
#
# iv8663C-iJs
#
# tzohvJ-Ryzk
#
# PEywWPHweXs
#
# ErfpC00pg_Q
#
# 2Kx0h7PYUBM
#
# rnfMN7sNt0A
#
# csTtWngid4Q
#
# ZblMr3hwVAY
#
# pUyh396qKa4
#
# QiiflDr1US0
#
# oijkPMxTBDs
#
# ACcGdoVua2c
#
# NrK5mkiXiDE
#
# UXalQpdboLI
#
# URlEY9hqow4
#
# PWr-5yvntF4
#
# SVzrX-dnFUQ
#
# 7Ls_ZneIDtg
#
# HfMnidWe0ns
#
# SAHNF93Y6V8
#
# XhmYVb5VJ_E
#
# HNX4fO9PzcU
#
# poQGCzhnNmE
#
# L78qU-kWR3M
#
# hY2C_Xszb98
#
# Kx0p5RvUpX0
#
# u8GF5pgj89A
#
# K4IiSrksQTs
#
# IPggzO3QMN4
#
# wRJ5FMtFBEA
#
# wC1XXyahTyk
#
# ADc2rtXJVDw
#
# Tzma7hfKeTY
#
# ZoQNWAyGgVQ
#
# hrf0hZREKNA
#
# fbOzwEcd8BM
#
# fDj4B26QUnY
#
# 9HAWmwxlXuY
#
# l7pkW3UIJb4
#
# uHIGjOd3098
#
# t5ESQvpQv0k
#
# W90Fayg7pcs
#
# M5wmY0UNeAE
#
# 058tu0BjL7I
#
# B7kdkXLXfmM
#
# lt2hALOgX44
#
# BF3HVE5kpXM
#
# UPKLfaShKeA
#
# rgc3NN4ab3c
#
# vxpKXBQf3uU
#
# 0yf7EftjowE
#
# NI6GglSJYBo
#
# yapfXpjbkrk
#
# c0iWCZtLJeI
#
# 9oq5_gLPm3A
#
# lBAaGfAZDHU
#
# 9AuW2Z7AUPo
#
# g-A9AMzLM_A
#
# aSjOUdV6GdM
#
# EI7AfGOqPek
#
# mnUwTE0Z5s8
#
# svZqqFfPdlw
#
# GGPGlD010hM
#
# bFFHx1LVZCU
#
# Ivi5yQ2wKa0
#
# OI9c0dRYjK4
#
# 98VisOT-X20
#
# H0FjhfGCk34
#
# viYU-AMnDXQ
#
# WdIdamCFUL4
#
# 9DjifaL6NKU
#
# cdZH93gTAT0
#
# jJI0CZ6ZU2M
#
# gRY_YLWKqO0
#
# 43BLSvt9KmU
#
# bXWG6-zg3RY
#
# T64_VlCdk2k
#
# WJNJn9JiN_M
#
# K74fzr5zubI
#
# L-ja5XenAy0
#
# 3b0apA33yOs
#
# KzILY2co8QI
#
# bmwgBFiAhbQ
#
# bDTy5hUnNJw
#
# it27qKKA3AI
#
# 4c5Tw9GlnHw
#
# ONXMqB-b5aU
#
# DHWZwKKvF10
#
# WdxEqCePUAE
#
# Gp4iQnVXoaI
#
# EIfa8FJh5DE
#
# YgcaTyVII7M
#
# 0bk-CvEcxQQ
#
# P73A4axl974
#
# _HyVfd8-5j0
#
# LtEw0FlQi5E
#
# 5zG85UO8I3w
#
# gwmK8s23r30
#
# EiTEgGrtt8g
#
# y2AL5K3wXfw
#
# z2NyhQL2unc
#
# UXHdmm8SS94
#
# RCR1UuOoW7Q
#
# PusVnneooMk
#
# cdPZeZwamZI
#
# nDIFQDS5ZJ8
#
# 5kmP8fKGGMI
#
# fviW6ZY83Ic
#
# S52F6qg3uBQ
#
# apQK4zrn9Ek
#
# r790HxSjlHw
#
# MR2Jj_PujBs
#
# UZ5cJYdRCxk
#
# Q32nBvPBdZw
#
# sCUxekJRHUk
#
# 6CsU_ChZAik
#
# vz5LmR5ECuU
#
# h3ll-nARb5E
#
# qX-KMLD1LUA
#
# KR5O7MQDrWc
#
# Y00uwk1QurE
#
# YDifgDAhMhU
#
# 3x8KEKlmq_A
#
# _TJLSboRegE
#
# 7X3QwIK3Rjc
#
# ZKAbeHipc-c
#
# S521HH1Zmi4
#
# _kh3gshTgK4
#
# Cb6whBkv-a4
#
# 8N52f61512Q
#
# oHsC6scl0nA
#
# zHYJxd3b_gI
#
# YoscXhxxgK0
#
# 7nB1q65RP8w
#
# TZRnhk6UlOM
#
# rDueo_V360w
#
# kjS0es_Ft_o
#
# 6IRsW_TkyVA
#
# 7tkbzxa8MFQ
#
# nJsgc6-JVXo
#
# rB0TYQBYZWY
#
# OuwC5cdTxGY
#
# R1j7v9nPq8o
#
# diJ-ARiKKEw
#
# NyxCiEVcjQc
#
# hWQw-pq6B-4
#
# Sw1QNlR9Dkw
#
# s1kwS3riCQI
#
# 4ngHS1m6DvY
#
# pv0vpgnAq4Y
#
# 8Y5Uqd4yWLo
#
# o_vdPE27RfY
#
# dRgG4MeNnUI
#
# VNFcJT2OY7s
#
# aoGgsP4VrcM
#
# qrtcNKDz6Ks
#
# AdMlC5D0nL8
#
# BNlp111zpwA
#
# yrD9bUgBzoQ
#
# MzFHWVkL4Gw
#
# oK44RrLWRFA
#
# vFKq0DGko_Y
#
# 232mcZGR2no
#
# wIyYJ6YD7IU
#
# SLpU2LGv54g
#
# dl8D8TlRfao
#
# Sam-K7I05vw
#
# 8tOoeEEvZSc
#
# KaKff4uG9U4
#
# r1vEBQ_V0v0
#
# my30dE2Je_A
#
# q7CMBrXy_10
#
# 52GEFUvfAlA
#
# g_TGYUr0Lcs
#
# p9tHSjDmFM0
#
# Ag6iqeiEmzM
#
# Hir86S-iFMA
#
# E1kVxMQlnPo
#
# PPRJeXAMd3U
#
# Q0y7xSULqpM
#
# v4-K7hUVujA
#
# fwjCWsvQhC8
#
# w426K2NL8kI
#
# OzM1duC9WwU
#
# IKvFz-IlB5k
#
# rJjlpAGAHq8
#
# pq0disSxH0M
#
# eein5vmtClk
#
# lsnjaJy4tW4
#
# AEG00iYJtrs
#
# tUuamR-ZS2M
#
# -bnyozSLQrE
#
# gf-CxpD6Db4
#
# yrpv2MI5H5Y
#
# CTdTOgai514
#
# a1olw9c-OPs
#
# qryqijbK5hQ
#
# FuD6pfHclM0
#
# fuSS_nxbCAU
#
# oNkL9Rm87CQ
#
# hx5GUdXMVOs
#
# VOx3OKP3nAE
#
# Fd1Kr8x4zZM
#
# S3jaKwAuT0w
#
# 1i9HWyx5R6A
#
# x0ETQEvbYCo
#
# HeEcBTmz5qM
#
# aYmB4-rqq3c
#
# WeX17mX3Tbo
#
# ovigswjn11Q
#
# sAA-rfO302w
#
# 3cbLQjXNB20
#
# isCrEzQQtd0
#
# x-bFRSObmbs
#
# rQaKWs0pq9w
#
# IJVDiqtIl3k
#
# hVPlfInnjE0
#
# wZHet5VbMXQ
#
# U6nGchwWYuQ
#
# 7EPu77UD67g
#
# gvzFBAPd0YA
#
# 3FxxSB3HLVw
#
# WxK8C7AuW9c
#
# 4J_amh3MLfo
#
# aqtSOksH-NE
#
# gpR2t3Rsypk
#
# uyco9vl9_iU
#
# W3PXRSTMElk
#
# tym51_uoeag
#
# wJ6FMjZkbMI
#
# uW3B6NQxGc0
#
# _ip61Z65wDQ
#
# 2nY0spA5UL4
#
# kX7_haBhTBY
#
# Zxyd8is2_mA
#
# Ei4XW0I2nyA
#
# HApPVQ8qFqs
#
# JUV-46ARdi0
#
# bfRaoWOZQxs
#
# 3WP0YKBLKIs
#
# qMrvDGgpgd0
#
# FWf7K9sbavQ
#
# 0IpbvXVbBYA
#
# zH87x_u5GcE
#
# MSAN-2CNMVo
#
# wog1R1d4zls
#
# RmuL-BPFi2Q
#
# BC19kwABFwc
#
# qxrrhNfse0w
#
# -MrXU5Ge1PM
#
# 8LkNcIB09Gg
#
# m29n1fBnxck
#
# ZmDBbnmKpqQ
#
# vMLk_T0PPbk
#
# p0lrFeOCDro
#
# oOl-D2GprD0
#
# LplwOft0d44
#
# m8DQgREJrdA
#
# Ld8S1M40n1c
#
# di7XhpKEWw4
#
# cqjBLtsrctg
#
# lgqKz1M4wTw
#
# 1zch8qWngIY
#
# GPTqY7Ih8PM
#
# USbnUoqtqJI
#
# 1EPqHMFf8k4
#
# J3PWR9TzaHs
#
# NStBVzTGMSU
#
# icvKR-97QrA
#
# -OZG4q6iSao
#
# wuRgEwm4FJI
#
# 8xTHF09MRSY
#
# FPLTf_3-FP0
#
# 3hxeiqfGqeg
#
# IunRV2HuEGs
#
# u4lzGzS_zEA
#
# GpFoGiscj7k
#
# RcCoHYkQLho
#
# f6JgGmIX1FM
#
# UB3PJwPMHzQ
#
# y49hkRuIRkM
#
# qdGIa3rymyc
#
# BJA8wjpI_Nk
#
# 0axJGDyJckg
#
# ONMcJ1L6y7s
#
# QN4-9HGK9AU
#
# eXk8XyuHXWs
#
# h7MYJghRWt0
#
# uy34su1wU_U
#
# 29skmwW7Rxk
#
# 6CFl2K1EyCg
#
# eHlgT3gRCPo
#
# a9x17nrqlx8
#
# zPPf1IMnTFM
#
# XvZy_emVTAs
#
# GwskncPKcsU
#
# 1g4vbuwyLJY
#
# BpBUY8ZUYd8
#
# ayIigZM3P6Y
#
# FLiMBtBXmuw
#
# s4GM69XB9Hs
#
# 6il00-wB-bs
#
# kHqL8_nqSXM
#
# mMbGQkvxVag
#
# 9LPXCGwSLAg
#
# 6MFcPDvPah4
#
# K340m2VwhqE
#
# XZvvfpCwXa8
#
# XYnMAnZTQu0
#
# IQWOxKJ81wE
#
# egvy7qhnIjA
#
# _K1AFfm78Zo
#
# EGGXBbst5Lo
#
# W0FE2Hjn30E
#
# 28wbnPU1vEc
#
# rc6b2wD0ZHE
#
# vKR0Drgf6vc
#
# U7-dxzp6Jvs
#
# nUtL5pbkuU8
#
# 9wpqZtIeSks
#
# 3tH195XLrWE
#
# 4n5bpeh5NNg
#
# NKM5BO0KmCk
#
# _XF338zgE14
#
# sbcTlugKHKI
#
# Gh8Gl2GwB6s
#
# KVMDaZUzcEI
#
# CuyTC8FLICY
#
# doc2TsxHJaA
#
# _Mi7bkz7msw
#
# ed17VfiFc4M
#
# zX3IyFUM5xc
#
# YIKfa86Btfs
#
# GzI_RfFB3uM
#
# kjqMFOcRpuI
#
# 3pjluP5vNug
#
# xPfpUcnKico
#
# KggCOIoPXPU
#
# YV9NrQvNEv4
#
# 4n3J2uIBqW4
#
# Y4BfaojXcWE
#
# _5EdJM8Zs0w
#
# bNjQUtXiX8o
#
# 0f3ZHuC-l0c
#
# 8B49S5n5cc4
#
# eW3V2rfVkKM
#
# _fei3yjsD3A
#
# 1OAIh8kv3ts
#
# OhxisV58nJw
#
# d6tljIFaIYI
#
# vjxq0mREBy8
#
# WAifgn2Cvo8
#
# nQ9CA6eVDJw
#
# pR4ljtuen1Q
#
# odB0e31J9tg
#
# w-Envep1jhc
#
# 5H3SC47cBpo
#
# 0gkdhI7HeQ4
#
# bbPQ6guxKUk
#
# hf9kaOO8Iro
#
# 8aBkpUe-ruk
#
# LJRjY2jlURA
#
# j3gmeEYFUs8
#
# 8aeW2Qz74Vo
#
# tQMZkGTQlI0
#
# yudS_7gT0Gg
#
# 3jYznNcoyuQ
#
# TMxp6aeCgxs
#
# 1WshT3oPXPk
#
# NGZUCTjyBrQ
#
# -V5NcSBFg2w
#
# _cAscqEUBh0
#
# qc0js3_moTU
#
# l6QMJniQWxQ
#
# _OwDKZQZiSk
#
# uHyVjF8pJQY
#
# wiQxi9EIxtI
#
# bHAAA9gcso0
#
# OhOSe3FUSwM
#
# qIp26CxXNJM
#
# 2Pz9cx6n2BU
#
# -zo9NBVpN_g
#
# z_o7dyT_tpM
#
# B7ALUGm1m2Q
#
# _Hil0oNKRdc
#
# 57n4dZAPxNY
#
# Ytrun6sxfmc
#
# Qc6R582N7F4
#
# OR3IgNZvoVs
#
# rJAKeNE3wvc
#
# kZmCTmCVpbM
#
# NpboOXdcq3g
#
# QWa7oXBlRDg
#
# SwNaxKk0AnQ
#
# GYkRPrAGSIw
#
# FDN-CFJcJpA
#
# dxxfVkXCk7Y
#
# OB-ehkRD4Bk
#
# MeyPwC9Pt_s
#
# Xdo8aWBq3tA
#
# KM1qvgy9g38
#
# _Hpi781-6oc
#
# 4qvqlK8Dc7M
#
# 0rOer3k2DWg
#
# dUtZWvan2v8
#
# CfYQHlfgqjk
#
# TYVAatAWGA8
#
# 2DhG8UcHkfM
#
# hmUyEDG7Jy0
#
# ODAeBfuRcpE
#
# tqiXwx0NG0Q
#
# Y953EmGss4Y
#
# l7iV-N41PdU
#
# oiunb1qDdJQ
#
# G2bx3FzgJ6o
#
# QRZJNqoJQFY
#
# psl3ZKgNmSc
#
# eKv5CBr-kKo
#
# AzQJO6AyfaQ
#
# Mz4C7zbb3HU
#
# FW5o2uBeMWQ
#
# jnp26RriUTw
#
# KogU5qdfvoc
#
# KfUExOXxU5Q
#
# yDr5gEdOcg4
#
# VyMqdTiNfcw
#
# sAzJrcryrDw
#
# cddAHfdiDE8
#
# VitJpehh0aM
#
# 3dwda4LxXeE
#
# hth250mmc6k
#
# rQLAI-vwqG0
#
# mH_LFkWxpI0
#
# rf0SZoCyzPs
#
# 0-Tm65i96TY
#
# yjG39WweOV8
#
# Xv6mpaNzu5M
#
# U50NuMNxVas
#
# JrG0F6yZt3Y
#
# IBfp6MCL4ck
#
# d8KPzY9BY4Q
#
# JJwEoHmteZE
#
# I4Ra4z2Arqg
#
# az47UTR8ZeA
#
# CYqwLTiye64
#
# WVRgXCouu8s
#
# auX_jBunrsE
#
# p6XBcQj5Hs4
#
# EpNsusxlJms
#
# D4vjPa8hvCM
#
# 1HesnepeVkU
#
# vkgGmzch9M8
#
# 6vVa6jiDQF8
#
# nZdOHfQsAJE
#
# GZIIEkhtEzk
#
# 95Abue3cl3g
#
# qsIeC_bYNCY
#
# ThnzTlBTXAU
#
# VvyDRDO6RLA
#
# OUTqP0YBzas
#
# C_Qc9R7M8-g
#
# Mk6ZzzWWJ1A
#
# ekzPebnuEls
#
# 5AJOOGuGn5U
#
# tnkPPRhfRvE
#
# MDzhVMuU6e8
#
# mJfIsZOCsYI
# 5052

# %%
def getInfoYouTubeVideo(id):
  request = youtube.videos().list(
          part=youtubeVideoParts,
          id=id,
          regionCode="VN"
      )
  response = request.execute()
  return response

# %%
df = []
# print(type(listIDs))
# print(listIDs)
# print(listIDs[0].split('\n')[0])
for id in listIDs:
  id = id.split('\n')[0]
  response = getInfoYouTubeVideo(id)
  print(len(response['items']))
  if len(response['items']) == 0:
    continue
  i = 0
  videoID = response['items'][i]['id']
  videoTitle = response['items'][i]['snippet']['title']
  videoPublishAt = response['items'][i]['snippet']['publishedAt']
  videoDescription = response['items'][i]['snippet']['description']
  videoChannelTitle = response['items'][i]['snippet']['channelTitle']
  videoTags = response['items'][i]['snippet'].get('tags')
  videoCategoryId = response['items'][i]['snippet']['categoryId']
  if response['items'][i]['snippet'].get('defaultAudioLanguage') is None: 
    videoDefaultAudioLanguage = ""
  else:  
    videoDefaultAudioLanguage = response['items'][i]['snippet']['defaultAudioLanguage']
  if 'defaultAudioLanguage' in response['items'][i]:
    print('hello')
  videoDuration = response['items'][i]['contentDetails']['duration']
  videoDimension = response['items'][i]['contentDetails']['dimension']
  videoDefinition = response['items'][i]['contentDetails']['definition']
  videoCaption = response['items'][i]['contentDetails']['caption']
  videoPrivacyStatus = response['items'][i]['status']['privacyStatus']
  videoEmbeddable = response['items'][i]['status']['embeddable']
  videoMakeForKids = response['items'][i]['status']['madeForKids']
  videoViewCount = response['items'][i]['statistics']['viewCount']
  videoLikeCount = response['items'][i]['statistics'].get('likeCount')
  videoDislikeCount = response['items'][i]['statistics'].get('dislikeCount')
  videoFavoriteCount = response['items'][i]['statistics'].get('favoriteCount')
  videoCommentCount = response['items'][i]['statistics'].get('commentCount')
  videoTopicCategories = response['items'][i].get('topicDetails')
  #videoTopicCategories = videoTopicCategories.get('topicCategories')
  if videoTopicCategories is None:
    videoTopicCategories=""
  else:
    videoTopicCategories = videoTopicCategories.get('topicCategories')
  videoDict = {
    'id': videoID,
    'publishAt': videoPublishAt,
    'title': videoTitle,
    'description': videoDescription,
    'channelTitle': videoChannelTitle,
    'tags': videoTags,
    'categoryId': videoCategoryId,
    'defaultAudioLanguage': videoDefaultAudioLanguage,
    'duration': videoDuration,
    'dimension': videoDimension,
    'definition': videoDefinition,
    'caption': videoCaption,
    'privacyStatus':videoPrivacyStatus,
    'embeddable': videoEmbeddable,
    'madeForKids': videoMakeForKids,
    'viewCount': videoViewCount,
    'likeCount': videoLikeCount,
    'dislikeCount': videoDislikeCount,
    'favoriteCount': videoFavoriteCount,
    'commentCount': videoCommentCount,
    'topicCategories': videoTopicCategories
  }
  df.append(videoDict)
display(pd.DataFrame(df))

# %%
pd.DataFrame(df).to_csv('list_info_02.csv', index=False)

# %%
pd.DataFrame(df).shape
# Out:
# (4962, 21)

# %%
videoDict = {
    'id': [videoID],
    'publishAt': [videoPublishAt],
    'title': [videoTitle],
    'description': [videoDescription],
    'channelTitle': [videoChannelTitle],
    'tags': [videoTags],
    'categoryId': [videoCategoryId],
    'defaultAudioLanguage': [videoDefaultAudioLanguage],
    'duration': [videoDuration],
    'dimension': [videoDimension],
    'definition': [videoDefinition],
    'caption': [videoCaption],
    'privacyStatus': [videoPrivacyStatus],
    'embeddable': [videoEmbeddable],
    'madeForKids': [videoMakeForKids],
    'viewCount': [videoViewCount],
    'likeCount': [videoLikeCount],
    'dislikeCount': [videoDislikeCount],
    'favoriteCount': [videoFavoriteCount],
    'commentCount': [videoCommentCount],
    'topicCategories': [videoTopicCategories]
}
